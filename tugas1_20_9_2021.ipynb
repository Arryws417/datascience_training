# %%
print("====Program Menghitung Bangun Ruang dan Bangun Datar===")
print("1. Lingkaran ")
print("2. Tabung ")
print("3. Prisma Segitiga ")
print("4. Kubus ")
print("5. Balok ")
print("6. Limas Segi Empat ")
pilih=int(input("Pilih ? "))
if pilih == 1:
  phi = 3.14
  jari=float (input("Masukan Nilai Jari-Jari = "))
  luas= phi*jari*jari
  keliling = phi*2*jari
  print("Luas Lingkaran = ",luas)
  print("Keliling Lingkaran = ",keliling)
elif pilih == 2:
  tinggi=int(input("Masukan Tinggi : "))
  jari=int(input("Masukan Jari-jari Lingkaran : "))
  phi=22/7
  luas=int(2*phi*jari*(tinggi+jari))
  volume=int((phi*(jari*jari))*tinggi)
  print ("Luas tabung = ", luas)
  print ("Volume tabung = ", volume)
elif pilih == 3:
  alas    = float(input("Masukan Nilai Alas = "))
  tinggi  = float(input("Masukan Nilai Tinggi ="))
  keliling_alas = float(input("Masukan Keliling = "))
  volume = 0.5*alas*tinggi
  print("Hasil Volume Prisma Adalah = ",volume)
  luas_alas =  2*alas+keliling_alas*tinggi
  print("Luas Permukaan Adalah = ",luas_alas)
else:
  print("Pilihan tidak ada!!")
  jwb=str(input("Apa ada Lagi ? "))
  if jwb == yes/Yes:
