# %%
import pandas as pd

# %% [markdown]
# LATIHAN MEMBUAT DATA FRAME

# %%
df1 = pd.DataFrame([
                    ["Arry", "L", 23, "Belum Menikah"],
                    ["Dyah", "P", 21, "Belum Menikah"],
                    ["Azizah", "P", 21, "Belum Menikah"],
                    ["Cindy", "P", 21, "Belum Menikah"],
                    ["Aulia", "P", 21, "Belum Menikah"]
])

df1.columns = ["Nama", "Jenis Kelamin", "Usia", "Status"]

df1

df1.to_csv('anggota_koperasi_sukanabung.csv')
df1.to_excel('anggota_koperasi_sukanabung.xlsx')

# %% [markdown]
# Bahas tentang fungsi yg ada di list (struktur data) dulu
#
# append() # Menambahkan elemen di akhir list (hanya 1)
# extend() # Menambahkan banyak elemen di akhir list
# index() # Mencari index dari elemen tertentu yang ada di list
# max(list) # Mencari elemen terbesar dari list
# min(list) # Mencari elemen terkecil dari list
# len(list) # Menghitung jumlah elemen dalam list
# clear() # Menghapus semua elemen dari list
# insert() # Memasukkan elemen baru pada urutan tertentu
# count() # Menghitung jumlah elemen dengan nilai tertentu
# pop() # Menghapus elemen terakhir dari list
# remove() # Menghapus elemen dengan nilai tertentu
# reverse() # Membalik urutan elemen dalam list
# copy() # Menduplikat elemen dalam list ke dalam variabel baru
# sort() # Mengurutkan (sorting)

# %%
tumpukan_warna = ['Blue', 'Red', 'Green', 'Purple', 'Black']
tumpukan_warna.append("Orange")
tumpukan_warna
# Out:
# ['Blue', 'Red', 'Green', 'Purple', 'Black', 'Jingga']

# %%
# extend, menambahkan banyak elemen di akhir list
tumpukan_warna.extend(['White','Tosca'])
tumpukan_warna
# Out:
# ['Black',
#  'Blue',
#  'Green',
#  'Jingga',
#  'Purple',
#  'Red',
#  'Tosca',
#  'White',
#  'White',
#  'Tosca']

# %%
#index. mencari indes dari nilai tertentu yang ada di list
tumpukan_warna.index('Green')
# Out:
# 2

# %%
#mencari nilai terkeci dari list
min(tumpukan_warna)
# Out:
# 'Black'

# %%
#mencari nilai terbesar dari list
max(tumpukan_warna)
# Out:
# 'White'

# %%
#sort untuk mengurutkan
tumpukan_warna.sort()
print(tumpukan_warna)
# Out:
# ['Black', 'Blue', 'Green', 'Jingga', 'Purple', 'Red', 'Tosca', 'White']

# %%
#clear, menghapus semua element dari list
tumpukan_warna.clear()
tumpukan_warna
# Out:
# []

# %%
#len, menghitung jumlah elemen dalam list
tumpukan_warna = ['blue','green','red','purple','black']
len(tumpukan_warna)
# Out:
# 5

# %%
#inster, memasukan elemen baru pada urutan tertentu
tumpukan_warna.insert(0,'orange')
tumpukan_warna
# Out:
# ['orange', 'blue', 'green', 'red', 'purple', 'black']

# %%
#remove, menghapus elemen dengan nilai tertentu
tumpukan_warna.remove('orange')
tumpukan_warna
# Out:
# ['blue', 'green', 'red', 'purple', 'black']

# %%
#reverse, membali urutan elemen dalam list
tumpukan_warna.reverse()
tumpukan_warna
# Out:
# ['black', 'purple', 'red', 'green', 'blue']

# %%
#pop, menghapus elemen terakhir dari list
tumpukan_warna.pop()
tumpukan_warna
# Out:
# ['black', 'purple', 'red', 'green']

# %%
#count , menghitung jumlah elemen dengan nilai tertentu
tumpukan_warna.count('blue')
# Out:
# 0

# %%
#copy, menduplikat elemen dalam list ke dalam variabel baru
tumpukan_warna2 = tumpukan_warna.copy()
tumpukan_warna2
# Out:
# ['black', 'purple', 'red', 'green']

# %%
#perbedaan fungsi copy dan re-assigment
a = [1,2,3]

# isi b sama dengan 1, tapi b hanya melakukan copy identitas objek a
b = a
c = a.copy()
#jika a[0] kita ubah, maka b[0] pun berubah
a[0] = 100

#fungsi id() dapat digunakan untuk mengetahui identitas
print("ID a : ",id(b))
print("ID b : ",id(a))
print("a : ",a)
print("b : ",b)

print("ID c : ",id(c))
print("c : ",c)
# Out:
# ID a :  140665385805936
# ID b :  140665385805936
# a :  [100, 2, 3]
# b :  [100, 2, 3]
# ID c :  140665386059088
# c :  [1, 2, 3]

# %% [markdown]
# STACK (Tumpukan)

# %%
angka = [1,3,5,3,3,5]
#stack -> first in last out
lemari = ["sarung","celana dasar","kemeja putih","selimut"]
lemari.append("jaket hoodie")
print(lemari)
# Out:
# ['sarung', 'celana dasar', 'kemeja putih', 'selimut', 'jaket hoodie']

# %%
#stack -> first in last out
lemari = ["sarung","celana","kemeja","selimut","jaket hoodie"]
lemari.pop()
print(lemari)
# Out:
# ['sarung', 'celana', 'kemeja', 'selimut']

# %% [markdown]
# QUEUE
# todo: Teori dan ilustrasi

# %%
#Queue -> first in first out
antrian_vaksin = ["Ary","Dyah","Azizah","Aulia","Cindy"]

antrian_vaksin.append("isabel")
print(antrian_vaksin)
# Out:
# ['Ary', 'Dyah', 'Azizah', 'Aulia', 'Cindy', 'isabel']

# %% [markdown]
# Activity
# 1. Code refactoring
# 1.1 Ubah gaya penulisan kode program berikut sesuai dengan standar PEP8

# %%
#program menghitung luas dan keliling lingkaran
phi = 3.14

def hitung_luas_lingkaran(jari_jari):
  luas = phi * jari_jari**2;
  return luas
def hitung_keliling_lingkaran(jari_jari):
  keling= 2*phi*jari_jari;
  return keling

def tampil_menu():
    print('')
    print("----------------------------------------------------")
    print( 'Program untuk menghitung luas dan keliling lingkaran')
    print( 'Mau ngitung apa nih bre?')
    print( '1. Luas Lingkaran')
    print( '2. Keliling Lingkaran')
    print( '3. Stop Program')
    print('')


pil = 'bukan 3'
while pil != 3:
    tampil_menu()
    pil = input ('Pilihan:')

    if pil=='1':
        jari_jari = input('Jari_Jari:')
        jari_jari = float(jari_jari)
        hasil = hitung_luas_lingkaran(jari_jari)
        print("Luas Lingkaran:", hasil )

    elif pil== '2':
        jari_jari=input ('Jari_Jari:')
        jari_jari=float (jari_jari)
        hsl=hitung_keliling_lingkaran(jari_jari)
        print("Keliling Lingkaran:", hsl )

    elif pil=='3':
        print( "TERIMA KASIH SUDAH MENGGUNAKAN PROGRAM KAMI")
        break

    else:
        print('Pilihan tidak tersedia')
        tampilkan_menu ()
# Out:
# ----------------------------------------------------
# Program untuk menghitung luas dan keliling lingkaran
# Mau ngitung apa nih bre?
# 1. Luas Lingkaran
# 2. Keliling Lingkaran
# 3. Stop Program
#
# Pilihan:2
# Jari_Jari:9
# Keliling Lingkaran: 56.52
#
# ----------------------------------------------------
# Program untuk menghitung luas dan keliling lingkaran
# Mau ngitung apa nih bre?
# 1. Luas Lingkaran
# 2. Keliling Lingkaran
# 3. Stop Program
#
# Pilihan:3
# TERIMA KASIH SUDAH MENGGUNAKAN PROGRAM KAMI

# %% [markdown]
# TUGAS 22/09/2021

# %%
pemain_dan_medali = [[7, "Ginting"], [5, "Jonathan C."], [9," Hendra"], [9," Ahsan"], [8, "Markus"], [8, "Kevin"], [4, "Gregoria"], 
                     [6, "Praven"], [6, "Melati"], [7, "Greysia"], [7, "Apriani"], [5, "Putri"], [5, "Rian"], [5, "Fajar"]]

# %%
# membuat list baru dengan mengurutkan list di atas berdasarkan medali yang diraih dari yg paling banyak
pemain_dan_medali = [[7, "Ginting"], [5, "Jonathan C."], [9, " Hendra"], [9, " Ahsan"], [8, "Markus"], [8, "Kevin"], [4, "Gregoria"], 
                     [6, "Praven"], [6, "Melati"], [7, "Greysia"], [7, "Apriani"], [5, "Putri"], [5, "Rian"], [5, "Fajar"]]

pemain_dan_medali.sort(reverse=True)
print(pemain_dan_medali)
# Out:
# [[9, ' Hendra'], [9, ' Ahsan'], [8, 'Markus'], [8, 'Kevin'], [7, 'Greysia'], [7, 'Ginting'], [7, 'Apriani'], [6, 'Praven'], [6, 'Melati'], [5, 'Rian'], [5, 'Putri'], [5, 'Jonathan C.'], [5, 'Fajar'], [4, 'Gregoria']]

# %%
# Dengan looping, buatlah 2 list terpisah dari pemain dan juga medalinya, namun urutannya harus tetap sama dengan yang diatas
pemain = ["Ginting", "Jonathan", "Hendra", "Ahsan", "Markus", "Kevin", "Gregoria", "Praven", "Melati", "Greysia", "Apriani",
          "Putri", "Rian", "Fajar"]
medali = [9,8,7,6,5,4,3,2,1]

while
